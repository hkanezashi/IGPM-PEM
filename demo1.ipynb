# %%
import sys
sys.path.append(".")

# %%
# %matplotlib inline
from patternmatching.gray import query_call

# %%
fname = "./sample/static/test1.json"
qargs = "--vertex a b c --edge x:a:b y:b:c z:c:a --vertexlabel a:cyan b:cyan c:cyan".split(" ")
query_call.run_query(fname, qargs, True, True)
# Out:
# Input Graph: 6 vertices, 8 edges
# Query Graph: 3 vertices, 3 edges
# Number of seeds: 6
# Found 2 patterns.
# Elapsed time 0.012564[s]:
# {0: <patternmatching.query.QueryResult.QueryResult at 0x122b5d7f0>,
#  2: <patternmatching.query.QueryResult.QueryResult at 0x122b5d630>}
