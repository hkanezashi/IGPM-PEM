# %%
import sys
sys.path.append(".")

# %%
# %matplotlib inline
from patternmatching.gray import query_call

# %%
fname = "./sample/test1.json"
qargs = "--vertex a b c d --edge x:a:b y:b:c z:c:d w:d:a --vertexlabel a:cyan b:cyan c:cyan d:cyan".split(" ")
query_call.run_query(fname, qargs, True, True)
# Out:
# Input Graph: 6 vertices, 8 edges
# Query Graph: 4 vertices, 4 edges
# Found 0 patterns.
# []
