# %%
import sys
sys.path.append(".")

# %%
# %matplotlib inline
from patternmatching.gray import query_call

# %%
fname = "./sample/test1.json"
qargs = "--vertex a b c --edge x:a:b y:b:c z:c:a --vertexlabel a:cyan b:cyan c:cyan".split(" ")
query_call.run_query(fname, qargs, True, True)
# Out:
# Input Graph: 6 vertices, 8 edges
# Query Graph: 3 vertices, 3 edges
# Found 2 patterns.
# [<patternmatching.query.QueryResult.QueryResult instance at 0x10c36a3f8>,
#  <patternmatching.query.QueryResult.QueryResult instance at 0x10c36ac68>]

# %%
fname = "sample/test1p.json"
qargs = "--vertex a b c --edge x:a:b y:b:c --path z:c:a --vertexlabel a:cyan b:cyan c:cyan --edgelabel x:yes y:yes z:yes".split(" ")
query_call.run_query(fname, qargs, True, True)
# Out:
# Input Graph: 6 vertices, 9 edges
# Query Graph: 3 vertices, 3 edges
# Found 13 patterns.
# [<patternmatching.query.QueryResult.QueryResult instance at 0x10c728638>,
#  <patternmatching.query.QueryResult.QueryResult instance at 0x10c820908>,
#  <patternmatching.query.QueryResult.QueryResult instance at 0x10c8207e8>,
#  <patternmatching.query.QueryResult.QueryResult instance at 0x10c820b48>,
#  <patternmatching.query.QueryResult.QueryResult instance at 0x10c820ef0>,
#  <patternmatching.query.QueryResult.QueryResult instance at 0x10c820a28>,
#  <patternmatching.query.QueryResult.QueryResult instance at 0x10c626638>,
#  <patternmatching.query.QueryResult.QueryResult instance at 0x10c626d40>,
#  <patternmatching.query.QueryResult.QueryResult instance at 0x10c6260e0>,
#  <patternmatching.query.QueryResult.QueryResult instance at 0x10c817fc8>,
#  <patternmatching.query.QueryResult.QueryResult instance at 0x10c8364d0>,
#  <patternmatching.query.QueryResult.QueryResult instance at 0x10c836710>,
#  <patternmatching.query.QueryResult.QueryResult instance at 0x10c836098>]
